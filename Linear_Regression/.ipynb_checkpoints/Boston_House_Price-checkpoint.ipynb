# %%
##########Boston Home Price Linear Regression ###################
# Amin Boroomand, December 2022
#Dataset: Diabete built-in Sickit Learn Dataset
#https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#objective: predicting music genre based on age and sex
#Algorithm: Linear Regression
###########################################################

# %%
#Imports
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sn
import pandas as pd

# %%
#Downloading the file
! wget https://github.com/dataprofessor/data/raw/master/BostonHousing.csv
# Out:
# --2022-12-27 21:29:31--  https://github.com/dataprofessor/data/raw/master/BostonHousing.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/BostonHousing.csv [following]
# --2022-12-27 21:29:32--  https://raw.githubusercontent.com/dataprofessor/data/master/BostonHousing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8001::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36242 (35K) [text/plain]
# Saving to: ‘BostonHousing.csv.2’
#
# BostonHousing.csv.2 100%[===================>]  35.39K  --.-KB/s    in 0.02s
#
# 2022-12-27 21:29:32 (2.20 MB/s) - ‘BostonHousing.csv.2’ saved [36242/36242]

# %%
#Reading the CSV file
Boston_H=pd.read_csv("BostonHousing.csv")
Boston_H.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#Setting the X and Y
#The last column, medV, is the Y variable. Other columns are X variables. 
Y=Boston_H.medv
X=Boston_H.drop(["medv"], axis=1)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
#setting the training and testing portions
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3)

# %%
#selecting the model
model=linear_model.LinearRegression()

# %%
#Training the model
model.fit(X_train,Y_train)
#using the model for prediction
Y_predict=model.predict(X_test)

# %%
#model metrics
print("Model Coefficients",model.coef_)
print("Model intercept %.2f" % model.intercept_)
print("coefficient of determination %.2f" % r2_score(Y_predict, Y_test))
print("Mean Squared Error %.2f" % mean_squared_error(Y_predict, Y_test))
# Out:
# Model Coefficients [-1.28087306e-01  5.15653113e-02 -2.76138304e-03  3.87276741e+00
#  -1.73021745e+01  4.32373850e+00 -9.72279329e-03 -1.72212417e+00
#   3.45015107e-01 -1.23167647e-02 -8.31394365e-01  1.37405108e-02
#  -4.91265855e-01]
# Model intercept 30.35
# coefficient of determination 0.64
# Mean Squared Error 21.41

# %%
sn.scatterplot(Y_test, Y_predict)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='medv'>
